# %%
import os

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_API_BASE = os.getenv("OPENAI_API_BASE")

# %%
from nih_proposal_rag_system.prompts.relevance_assessment import assess_relevance

topic = "Tumor Microenvironment Remodeling"
target = "Developing computational methods for predicting immunotherapy response"

assessment = assess_relevance(topic, target)
assessment
# Out:
# {'relevance_score': 4,
#  'justification': 'Tumor microenvironment remodeling plays a critical role in influencing immune responses and the effectiveness of immunotherapy. Understanding the dynamics of the tumor microenvironment can enhance computational models aimed at predicting how tumors will respond to immunotherapy, making this topic highly relevant to the target research direction.'}
